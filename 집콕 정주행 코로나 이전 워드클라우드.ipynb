# %%
import pandas as pd

# %%
before_cd = pd.read_csv('c:/py_data/py_project/Before 코로나 단어집계(집콕정주행).csv', encoding='cp949')

# %%
del before_cd['Unnamed: 0']
before_cd
# Out:
#           단어   횟수
# 0        드라마  463
# 1         생각  432
# 2         엄마  365
# 3         카페  335
# 4         영화  288
# ...      ...  ...
# 12226     할꼬    1
# 12227     한인    1
# 12228    거북이    1
# 12229     금색    1
# 12230  스트레이트    1
#
# [12231 rows x 2 columns]

# %%
cd = dict(before_cd.values.tolist())
cd
# Out:
# {'드라마': 463,
#  '생각': 432,
#  '엄마': 365,
#  '카페': 335,
#  '영화': 288,
#  '바로': 278,
#  '저녁': 262,
#  '영상': 256,
#  '아침': 238,
#  '정주': 229,
#  '주말': 226,
#  '추천': 210,
#  '오빠': 202,
#  '친구': 200,
#  '일상': 198,
#  '마음': 196,
#  '언니': 190,
#  '남편': 185,
#  '사랑': 183,
#  '아빠': 183,
#  '선물': 183,
#  '사실': 181,
#  '복사': 180,
#  '도움말': 180,
#  '이상': 174,
#  '다음': 174,
#  '커피': 172,
#  '행복': 168,
#  '집': 166,
#  '노래': 164,
#  '점심': 164,
#  '맥주': 156,
#  '이야기': 155,
#  '아직': 154,
#  '가지': 149,
#  '주문': 148,
#  '맛집': 144,
#  '느낌': 142,
#  '연휴': 140,
#  '기분': 139,
#  '시즌': 137,
#  '아기': 136,
#  '오늘': 133,
#  '퇴근': 131,
#  '전': 129,
#  '혼자': 129,
#  '병원': 128,
#  '집콕': 127,
#  '치킨': 127,
#  '화질': 126,
#  '일': 124,
#  '출근': 124,
#  '보기': 123,
#  '최고': 123,
#  '여행': 122,
#  '아이': 120,
#  '거리': 120,
#  '트랙': 120,
#  '넷플릭스': 116,
#  '기도': 116,
#  '선택': 116,
#  '시간': 116,
#  '다리': 114,
#  '날씨': 114,
#  '위해': 114,
#  '먹기': 114,
#  '소스': 113,
#  '언제': 111,
#  '블로그': 111,
#  '포스팅': 110,
#  '블랙': 110,
#  '월요일': 110,
#  '동안': 109,
#  '웹툰': 109,
#  '준비': 108,
#  '하늘': 108,
#  '부산': 108,
#  '음식': 107,
#  '종일': 107,
#  '것': 105,
#  '구경': 105,
#  '배우': 103,
#  '원래': 101,
#  '갑자기': 101,
#  '서울': 100,
#  '여름': 100,
#  '가족': 99,
#  '지나': 99,
#  '일요일': 98,
#  '마무리': 98,
#  '운동': 97,
#  '먹음': 96,
#  '고민': 95,
#  '한국': 95,
#  '인생': 93,
#  '세상': 93,
#  '수': 93,
#  '그녀': 93,
#  '때': 92,
#  '데이': 92,
#  '회사': 90,
#  '메뉴': 89,
#  '근처': 89,
#  '보이': 89,
#  '보고': 89,
#  '벌써': 88,
#  '재미': 87,
#  '티비': 87,
#  '일찍': 86,
#  '도착': 86,
#  '아가': 86,
#  '더': 85,
#  '일단': 85,
#  '고기': 85,
#  '재생': 85,
#  '바람': 83,
#  '토요일': 83,
#  '여운': 82,
#  '방송': 82,
#  '기억': 82,
#  '던데': 81,
#  '가야': 81,
#  '의사': 81,
#  '모습': 80,
#  '기능': 80,
#  '미세먼지': 80,
#  '이건': 80,
#  '길이': 80,
#  '이유': 79,
#  '내일': 79,
#  '다행': 78,
#  '자주': 78,
#  '이벤트': 78,
#  '시리즈': 78,
#  '뭔가': 78,
#  '장님': 78,
#  '금요일': 78,
#  '드디어': 78,
#  '크리스마스': 77,
#  '태풍': 77,
#  '예약': 77,
#  '나노': 76,
#  '분위기': 76,
#  '드론': 76,
#  '여서': 76,
#  '동네': 76,
#  '일어': 76,
#  '동영상': 75,
#  '이름': 74,
#  '하루': 74,
#  '추석': 73,
#  '모두': 73,
#  '치즈': 73,
#  '안내': 72,
#  '관련': 72,
#  '얼굴': 72,
#  '덕분': 71,
#  '고요': 71,
#  '과자': 71,
#  '좀': 71,
#  '요': 70,
#  '존맛': 70,
#  '꿀떡': 70,
#  '출연': 70,
#  '수업': 68,
#  '떡볶이': 68,
#  '예전': 68,
#  '고마': 68,
#  '사이': 68,
#  '내내': 68,
#  '포장': 68,
#  '주소': 68,
#  '돼지': 67,
#  '침대': 67,
#  '거나': 67,
#  '피자': 67,
#  '캐슬': 66,
#  '마우스': 66,
#  '놀이': 66,
#  '화면': 65,
#  '안녕': 65,
#  '옵션': 65,
#  '발견': 65,
#  '간식': 65,
#  '아들': 65,
#  '케이크': 64,
#  '스카이': 64,
#  '가을': 64,
#  '약속': 64,
#  '사용': 64,
#  '나름': 64,
#  '동생': 63,
#  '눈물': 63,
#  '라면': 63,
#  '겨울': 63,
#  '정리': 62,
#  '유니': 62,
#  '오후': 62,
#  '기초': 62,
#  '매일': 62,
#  '회': 61,
#  '외출': 61,
#  '공부': 61,
#  '파서': 61,
#  '얼른': 61,
#  '플레이어': 61,
#  '내용': 61,
#  '래그': 60,
#  '지금': 60,
#  '광고정보': 60,
#  '파티': 60,
#  '만족': 60,
#  '아야': 60,
#  '디자인': 60,
#  '예정': 60,
#  '산책': 60,
#  '멀티': 60,
#  '레이어': 60,
#  '선거': 60,
#  '배달': 60,
#  '공유소스': 60,
#  '마트': 60,
#  '음소거': 60,
#  '우측': 60,
#  '라이센스': 60,
#  '인코딩': 60,
#  '걱정': 59,
#  '생일': 59,
#  '일주일': 59,
#  '낮잠': 59,
#  '여주': 59,
#  '구들': 58,
#  '미리': 58,
#  '파스타': 58,
#  '지고': 58,
#  '자꾸': 58,
#  '이불': 58,
#  '세트': 57,
#  '여유': 57,
#  '고생': 57,
#  '자율': 57,
#  '가장': 57,
#  '환자': 57,
#  '안나': 57,
#  '구매': 56,
#  '진짜': 56,
#  '해도': 56,
#  '스토리': 56,
#  '스타일': 56,
#  '인기': 55,
#  '생활': 55,
#  '거': 55,
#  '가면': 55,
#  '올해': 55,
#  '건강': 55,
#  '가격': 55,
#  '이사': 55,
#  '다리미': 54,
#  '공연': 54,
#  '학교': 54,
#  '항상': 54,
#  '이': 54,
#  '바다': 54,
#  '비행기': 54,
#  '간만': 54,
#  '와중': 54,
#  '먼저': 53,
#  '추억': 53,
#  '년': 53,
#  '가능': 53,
#  '수다': 53,
#  '제품': 53,
#  '반찬': 53,
#  '요즘': 53,
#  '작품': 52,
#  '나니': 52,
#  '명절': 52,
#  '버스': 52,
#  '이모': 52,
#  '무료': 52,
#  '신랑': 52,
#  '하자': 52,
#  '공감': 52,
#  '컬러': 51,
#  '디저트': 51,
#  '휴가': 51,
#  '주인공': 51,
#  '새벽': 51,
#  '남자': 51,
#  '캐릭터': 51,
#  '간다': 51,
#  '무조건': 51,
#  '추가': 50,
#  '아이스': 50,
#  '방문': 50,
#  '해먹': 50,
#  '콩나물': 50,
#  '떡뻥': 50,
#  '요한': 50,
#  '토리': 50,
#  '박스': 49,
#  '리지': 49,
#  '진행': 49,
#  '나중': 49,
#  '자기': 49,
#  '얼마': 49,
#  '타임': 49,
#  '번': 49,
#  '인스타': 49,
#  '개봉': 48,
#  '미러': 48,
#  '저희': 48,
#  '이번': 48,
#  '동백꽃': 47,
#  '공기': 47,
#  '소개': 47,
#  '과일': 47,
#  '뭐': 47,
#  '취향': 47,
#  '뷰티': 46,
#  '얼마나': 46,
#  '유튜브': 46,
#  '소리': 46,
#  '당근': 46,
#  '야채': 46,
#  '사서': 46,
#  '주신': 46,
#  '시원': 46,
#  '은지': 46,
#  '공기청정기': 46,
#  '안보': 46,
#  '그릇': 46,
#  '오전': 45,
#  '맘': 45,
#  '또': 45,
#  '혹시': 45,
#  '아마': 45,
#  '다시': 45,
#  '냄새': 45,
#  '동시': 45,
#  '해': 45,
#  '무지': 45,
#  '쇼핑': 45,
#  '얘기': 45,
#  '양념': 45,
#  '살짝': 44,
#  '잠깐': 44,
#  '전부': 44,
#  '기대': 44,
#  '오기': 44,
#  '롯데': 44,
#  '필터': 44,
#  '아해': 44,
#  '대로': 44,
#  '작가': 44,
#  '볶음밥': 44,
#  '김치': 44,
#  '갈비': 44,
#  '수가': 43,
#  '요리': 43,
#  '그림': 43,
#  '제대로': 43,
#  '이후': 43,
#  '게임': 43,
#  '아이스크림': 43,
#  '대기': 43,
#  '로맨스': 43,
#  '연기': 43,
#  '심심': 43,
#  '순이': 42,
#  '여러': 42,
#  '세계': 42,
#  '우린': 42,
#  '그냥': 42,
#  '감독': 42,
#  '관람': 42,
#  '사람': 42,
#  '이유식': 42,
#  '행사': 42,
#  '볶음': 42,
#  '통증': 42,
#  '멜로': 42,
#  '화요일': 42,
#  '오래': 42,
#  '유명': 42,
#  '관심': 42,
#  '평소': 42,
#  '일본': 42,
#  '이제': 41,
#  '무엇': 41,
#  '한번': 41,
#  '라떼': 41,
#  '정신': 41,
#  '제': 41,
#  '우리': 41,
#  '영어': 41,
#  '수요일': 41,
#  '며칠': 41,
#  '었다': 40,
#  '성공': 40,
#  '꾹꾹': 40,
#  '사이즈': 40,
#  '검사': 40,
#  '애': 40,
#  '카레': 40,
#  '제거': 40,
#  '마치': 40,
#  '정말': 40,
#  '혜림이': 40,
#  '날': 40,
#  '월': 40,
#  '여러분': 40,
#  '간단': 40,
#  '온천천': 40,
#  '중인': 40,
#  '거기': 39,
#  '해지': 39,
#  '센스': 39,
#  '쿠키': 39,
#  '삼겹살': 39,
#  '이도': 39,
#  '용': 39,
#  '패션': 39,
#  '미용실': 39,
#  '이케아': 39,
#  '매력': 39,
#  '리기': 39,
#  '전화': 39,
#  '박준': 38,
#  '각하': 38,
#  '신기': 38,
#  '고이': 38,
#  '공간': 38,
#  '와인': 38,
#  '누가': 38,
#  '소고기': 38,
#  '순간': 38,
#  '지난': 38,
#  '식당': 38,
#  '가보': 38,
#  '시그널': 38,
#  '가요': 37,
#  '연출': 37,
#  '저번': 37,
#  '부분': 37,
#  '장면': 37,
#  '작년': 37,
#  '감기': 37,
#  '어찌': 37,
#  '첫째': 37,
#  '오지': 37,
#  '다이어트': 37,
#  '집중': 37,
#  '대신': 37,
#  '어제': 37,
#  '다이어리': 37,
#  '만두': 37,
#  '쿠폰': 37,
#  '여보': 36,
#  '튀김': 36,
#  '검색': 36,
#  '중간': 36,
#  '대충': 36,
#  '마리': 36,
#  '커플': 36,
#  '피곤': 36,
#  '목요일': 36,
#  '간장': 36,
#  '둘째': 36,
#  '그': 35,
#  '조심': 35,
#  '한잔': 35,
#  '직접': 35,
#  '미니': 35,
#  '그때': 35,
#  '내년': 35,
#  '중': 35,
#  '만원': 35,
#  '장소': 35,
#  '나': 35,
#  '계획': 35,
#  '주차': 35,
#  '서도': 35,
#  '육아': 35,
#  '카카오페이지': 35,
#  '기자': 35,
#  '실내': 35,
#  '볼': 35,
#  '대박': 35,
#  '편': 35,
#  '스벅': 35,
#  '기묘': 34,
#  '구입': 34,
#  '외식': 34,
#  '인분': 34,
#  '일기': 34,
#  '할인': 34,
#  '특별': 34,
#  '부시': 34,
#  '미래': 34,
#  '음으로': 34,
#  '표정': 34,
#  '후': 34,
#  '플레이': 34,
#  '남아': 34,
#  '필수': 34,
#  '애기': 34,
#  '최근': 34,
#  '강철': 34,
#  '야식': 34,
#  '공개': 34,
#  '현실': 34,
#  '물놀이': 34,
#  '잡고': 34,
#  '식사': 34,
#  '모닝': 34,
#  '국물': 34,
#  '포인트': 34,
#  '주시': 34,
#  '네이버': 34,
#  '시영': 34,
#  '분': 33,
#  '감사': 33,
#  '작업': 33,
#  '리하': 33,
#  '눈': 33,
#  '분명': 33,
#  '인형': 33,
#  '안': 33,
#  '주변': 33,
#  '겨우': 33,
#  '시작': 33,
#  '널': 33,
#  '이하': 33,
#  '양파': 33,
#  '말': 33,
#  '나이': 33,
#  '케이스': 33,
#  '다지': 32,
#  '여자': 32,
#  '펭수': 32,
#  '스트레스': 32,
#  '반복': 32,
#  '미안': 32,
#  '귀가': 32,
#  '카드': 32,
#  '자신': 32,
#  '음료': 32,
#  '밀크': 32,
#  '니지': 32,
#  '고고': 32,
#  '초코': 32,
#  '마취': 32,
#  '잔뜩': 32,
#  '어진': 32,
#  '루솔': 32,
#  '웨이': 32,
#  '슈퍼': 32,
#  '방콕': 32,
#  '딸기': 32,
#  '시험': 32,
#  '두번째': 32,
#  '위': 32,
#  '옛날': 32,
#  '데리': 32,
#  '난리': 32,
#  '라거': 32,
#  '부부': 32,
#  '스타': 32,
#  '가끔': 32,
#  '주': 32,
#  '차요': 32,
#  '라가': 32,
#  '못': 32,
#  '빨래': 32,
#  '테이블': 32,
#  '오니': 31,
#  '기전': 31,
#  '쿠션': 31,
#  '아래': 31,
#  '시': 31,
#  '운전': 31,
#  '어플': 31,
#  '포기': 31,
#  '제발': 31,
#  '맞이': 31,
#  '조만간': 31,
#  '불편': 31,
#  '나머지': 31,
#  '여전': 31,
#  '헤어': 31,
#  '인테리어': 31,
#  '서로': 31,
#  '달달': 31,
#  '체험': 31,
#  '보시': 31,
#  '완료': 31,
#  '필요': 31,
#  '그게': 31,
#  '계란': 30,
#  '컨트롤러': 30,
#  '자체': 30,
#  '연말': 30,
#  '위인': 30,
#  '인천': 30,
#  '마카롱': 30,
#  '다그': 30,
#  '졸업': 30,
#  '등': 30,
#  '주기': 30,
#  '결혼식': 30,
#  '감동': 30,
#  '도전': 30,
#  '김밥': 30,
#  '책': 30,
#  '지게': 30,
#  '모양': 30,
#  '기고': 30,
#  '천원': 30,
#  '금방': 30,
#  '청소': 30,
#  '그것': 30,
#  '스팀': 30,
#  '어린이집': 30,
#  '구시': 30,
#  '이로': 30,
#  '알바': 30,
#  '교수': 30,
#  '귀걸이': 30,
#  '크림': 30,
#  '런가': 30,
#  '예능': 30,
#  '상태': 29,
#  '부동산': 29,
#  '해장': 29,
#  '구름': 29,
#  '데이터': 29,
#  '바퀴': 29,
#  '보리': 29,
#  '오픈': 29,
#  '상황': 29,
#  '사진': 29,
#  '거지': 29,
#  '마블': 29,
#  '출산': 29,
#  '최애': 29,
#  '정보': 29,
#  '비밀': 29,
#  '감성': 29,
#  '다이소': 29,
#  '할머니': 29,
#  '누구': 29,
#  '사건': 28,
#  '블루': 28,
#  '달': 28,
#  '지랄': 28,
#  '확인': 28,
#  '서비스': 28,
#  '셀카': 28,
#  '완성': 28,
#  '조합': 28,
#  '만하': 28,
#  '노을': 28,
#  '스티커': 28,
#  '신경': 28,
#  '부담': 28,
#  '고구마': 28,
#  '존재': 28,
#  '축제': 28,
#  '에어': 28,
#  '워낙': 28,
#  '시기': 28,
#  '매우': 28,
#  '인증': 28,
#  '목소리': 28,
#  '치면': 28,
#  '도국': 28,
#  '왜': 28,
#  '힐링': 28,
#  '네일': 28,
#  '요거트': 28,
#  '배부': 28,
#  '당신': 28,
#  '계란찜': 28,
#  '겨울왕국': 28,
#  '내부': 28,
#  '새우': 28,
#  '평일': 28,
#  '범례': 28,
#  '도': 28,
#  '그나': 28,
#  '조절': 28,
#  '솔직': 28,
#  '편의점': 28,
#  '점심시간': 28,
#  '결제': 28,
#  '순위': 28,
#  '참고': 28,
#  '점점': 28,
#  '경제': 28,
#  '붕어빵': 28,
#  '감정': 27,
#  '기록': 27,
#  '모임': 27,
#  '고급': 27,
#  '소주': 27,
#  '계절': 27,
#  '기본': 27,
#  '약간': 27,
#  '카톡': 27,
#  '브라운': 27,
#  '네': 27,
#  '창문': 27,
#  '임신': 27,
#  '냉장고': 27,
#  '채널': 27,
#  '연락': 27,
#  '통해': 27,
#  '만들기': 27,
#  '마늘': 27,
#  '웃기': 27,
#  '이용': 26,
#  '확실': 26,
#  '끼리': 26,
#  '공원': 26,
#  '수록': 26,
#  '일어나서': 26,
#  '대한': 26,
#  '일정': 26,
#  '중드': 26,
#  '고객': 26,
#  '기술': 26,
#  '말씀': 26,
#  '슬슬': 26,
#  '친정': 26,
#  '차': 26,
#  '프로그램': 26,
#  '때문': 26,
#  '강아지': 26,
#  '만난': 26,
#  '유기농': 26,
#  '폭풍': 26,
#  '연속': 26,
#  '둘이서': 26,
#  '주먹밥': 26,
#  '백화점': 26,
#  '린다': 26,
#  '당면': 26,
#  '리스트': 26,
#  '시드니': 26,
#  '버터': 26,
#  '계속': 26,
#  '감자': 26,
#  '의미': 26,
#  '듯이': 26,
#  '또한': 25,
#  '막상': 25,
#  '예고편': 25,
#  '고양이': 25,
#  '대해': 25,
#  '왼쪽': 25,
#  '구성': 25,
#  '한참': 25,
#  '대학생': 25,
#  '등등': 25,
#  '심지어': 25,
#  '작성': 25,
#  '목표': 25,
#  '휴무': 25,
#  '이틀': 25,
#  '브이': 25,
#  '학원': 25,
#  '컨디션': 25,
#  '뚝딱': 25,
#  '본방': 25,
#  '기준': 25,
#  '후기': 25,
#  '집안일': 25,
#  '콘서트': 25,
#  '새해': 25,
#  '에어컨': 25,
#  '토스트': 25,
#  '위로': 25,
#  '버섯': 24,
#  '브런치': 24,
#  '까운': 24,
#  '핫도그': 24,
#  '노력': 24,
#  '수도': 24,
#  '그러케': 24,
#  '원피스': 24,
#  '김치찌개': 24,
#  '등장': 24,
#  '기하': 24,
#  '그거': 24,
#  '잠시': 24,
#  '제주도': 24,
#  '편이': 24,
#  '나들이': 24,
#  '가게': 24,
#  '이면': 24,
#  '바닥': 24,
#  '초밥': 24,
#  '듬뿍': 24,
#  '인물': 24,
#  '화이팅': 24,
#  '안해': 24,
#  '증말': 24,
#  '달리': 24,
#  '밴드': 24,
#  '주차장': 24,
#  '대구': 24,
#  '문제': 24,
#  '대상': 24,
#  '구이': 24,
#  '소품': 24,
#  '오른쪽': 24,
#  '우유': 24,
#  '의자': 24,
#  '었는데': 24,
#  '출처': 24,
#  '당장': 24,
#  '시청': 24,
#  '후다닥': 24,
#  '진심': 24,
#  '액션': 24,
#  '다나': 24,
#  '보관': 24,
#  '무대': 24,
#  '차로': 24,
#  '기간': 24,
#  '지창욱': 24,
#  '정화': 24,
#  '벚꽃': 24,
#  '사주': 24,
#  '강제': 24,
#  '냉동': 24,
#  '끝내': 24,
#  '먼지': 24,
#  '파트너': 23,
#  '지인': 23,
#  '아지': 23,
#  '행차': 23,
#  '성격': 23,
#  '제주': 23,
#  '년전': 23,
#  '안주': 23,
#  '이기': 23,
#  '경기도': 23,
#  '크게': 23,
#  '피부': 23,
#  '보지': 23,
#  '한지': 23,
#  '센터': 23,
#  '불금': 23,
#  '체력': 23,
#  '페이': 23,
#  '만해': 23,
#  '장르': 23,
#  '코스': 23,
#  '라이트': 23,
#  '역시': 23,
#  '노트북': 23,
#  '후회': 23,
#  '돈까스': 23,
#  '시절': 23,
#  '보라': 23,
#  '만남': 23,
#  '도쿄': 23,
#  '판매': 23,
#  '부족': 22,
#  '득템': 22,
#  '고추': 22,
#  '뚝배기': 22,
#  '걸': 22,
#  '통닭': 22,
#  '부작': 22,
#  '디즈니': 22,
#  '댓글': 22,
#  '어묵': 22,
#  '어른': 22,
#  '위치': 22,
#  '참여': 22,
#  '워홀': 22,
#  '에버랜드': 22,
#  '절대': 22,
#  '색깔': 22,
#  '무려': 22,
#  '엽떡': 22,
#  '종종': 22,
#  '메인': 22,
#  '브랜드': 22,
#  '려면': 22,
#  '살이': 22,
#  '가다가': 22,
#  '진료': 22,
#  '가구': 22,
#  '설': 22,
#  '과제': 22,
#  '미국': 22,
#  '신기하': 22,
#  '닥터': 22,
#  '안고': 22,
#  '이자': 22,
#  '구월동': 22,
#  '가방': 22,
#  '하라': 22,
#  '기름': 22,
#  '내기': 22,
#  '노잼': 22,
#  '궁금': 22,
#  '닭갈비': 22,
#  '자연': 22,
#  '다양': 22,
#  '단지': 22,
#  '국내': 22,
#  '장난': 22,
#  '서울특별시': 22,
#  '포토': 22,
#  '판타지': 22,
#  '축하': 22,
#  '토욜': 22,
#  '티켓': 22,
#  '보아': 22,
#  '하나': 22,
#  '배송': 22,
#  '핑크': 22,
#  '인사': 21,
#  '고해': 21,
#  '다크': 21,
#  '임산부': 21,
#  '심장': 21,
#  '돌이': 21,
#  '더욱': 21,
#  '곱창': 21,
#  '일차': 21,
#  '취소': 21,
#  '지방': 21,
#  '지면': 21,
#  '눈치': 21,
#  '루나': 21,
#  '현빈': 21,
#  '다운': 21,
#  '입맛': 21,
#  '정도': 21,
#  '호텔': 21,
#  '소화': 21,
#  '행해': 21,
#  '그날': 21,
#  '인터넷': 21,
#  '이전': 21,
#  '유럽': 21,
#  '오일': 21,
#  '샐러드': 21,
#  '투어': 21,
#  '어마': 21,
#  '마침': 21,
#  '얼집': 21,
#  '묵향': 21,
#  '우리동네': 21,
#  '당일': 21,
#  '효과': 21,
#  '보통': 21,
#  '라이브': 21,
#  '나무': 21,
#  '의학과': 20,
#  '연어': 20,
#  '결정': 20,
#  '김소연': 20,
#  '인적': 20,
#  '최대한': 20,
#  '동하': 20,
#  '리뷰': 20,
#  '사장': 20,
#  '심해': 20,
#  '코스트코': 20,
#  '치과': 20,
#  '야근': 20,
#  '신전': 20,
#  '짜증': 20,
#  '남녀': 20,
#  '화이트': 20,
#  '적당': 20,
#  '엠버': 20,
#  '두시': 20,
#  '아름': 20,
#  '죽음': 20,
#  '물어': 20,
#  '가슴': 20,
#  '산모': 20,
#  '이웃': 20,
#  '상우': 20,
#  '신세계': 20,
#  '데이트': 20,
#  '등원': 20,
#  '첫사랑': 20,
#  '러브': 20,
#  '결말': 20,
#  '생기': 20,
#  '클리어': 20,
#  ...}

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import random
img_path = 'c:/py_data/TV.jpg'
cloud_mask = np.array(Image.open(img_path))


wordcloud = WordCloud(font_path="c:/Windows/Fonts/malgun.ttf", 
                      colormap='OrRd',
                      background_color="white", mask=cloud_mask)
wc = wordcloud.generate_from_frequencies(cd)
plt.figure(figsize=(30,40))
plt.imshow(wc)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
