# %%
import pandas as pd
import requests     # 웹 서버에 요청을 보내고 응답을 받는 라이브러리

# %%
client_id = 'UWHF47Ojv3VPR1mQx_xa'
client_secret = 'kvL2c2dFMA'

# %%
keyword = input('네이버 뉴스 검색어 입력: ')
# Out:
# 네이버 뉴스 검색어 입력: 어버이날

# %%
url = "https://openapi.naver.com/v1/search/news?query=" + keyword # json 결과
print(url)
# Out:
# https://openapi.naver.com/v1/search/news?query=어버이날

# %%
# clientID, client Secret -> 요청 header로 전송
headers = {'X-Naver-Client-Id': client_id,
           'X-Naver-Client-Secret': client_secret}

# %%
response_data = requests.get(url, headers=headers)
response_data
# Out:
# <Response [200]>

# %%
temp_data = response_data.json()
temp_data
# Out:
# {'lastBuildDate': 'Thu, 06 May 2021 15:13:27 +0900',
#  'total': 124600,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '어머니 가슴이 아닌, 유리창에 카네이션을…코로나에 가슴 미어지는 자녀들',
#    'originallink': 'http://www.idaegu.com/newsView/idg202105060013',
#    'link': 'http://www.idaegu.com/newsView/idg202105060013',
#    'description': '대구시에 살고있는 A(여)씨가 <b>어버이날</b>을 앞둔 지난 5일 중증 치매로 거동이 불편해 동명의 한 요양원에... A씨에게는 이날 면회가 <b>어버이날</b>을 앞둔 시점이라 더욱 특별했다. 혹시나 하는 기대로 카네이션과 꽃다발을... ',
#    'pubDate': 'Thu, 06 May 2021 15:12:00 +0900'},
#   {'title': '진천군, <b>어버이</b>의 <b>날</b> 맞이 물품꾸러미 전달',
#    'originallink': 'http://www.gukjenews.com/news/articleView.html?idxno=2217974',
#    'link': 'http://www.gukjenews.com/news/articleView.html?idxno=2217974',
#    'description': '이날 전달된 꾸러미는 파도타기 회원들이 각자의 재능을 기부해 만든 <b>어버이 날</b> 카네이션, 풍선장식 축하 케이크 등으로 구성됐다. 송기섭 군수는 &quot;모두가 어려운 시기인데 나보다 남을 생각하는 마음으로 꾸러미 준비 등... ',
#    'pubDate': 'Thu, 06 May 2021 15:12:00 +0900'},
#   {'title': "농협생명, 농촌·지역사회 나눔 활동 'ESG 애쓰자' 캠페인",
# ...

# %%
temp_data['items'][0]
# Out:
# {'title': '어머니 가슴이 아닌, 유리창에 카네이션을…코로나에 가슴 미어지는 자녀들',
#  'originallink': 'http://www.idaegu.com/newsView/idg202105060013',
#  'link': 'http://www.idaegu.com/newsView/idg202105060013',
#  'description': '대구시에 살고있는 A(여)씨가 <b>어버이날</b>을 앞둔 지난 5일 중증 치매로 거동이 불편해 동명의 한 요양원에... A씨에게는 이날 면회가 <b>어버이날</b>을 앞둔 시점이라 더욱 특별했다. 혹시나 하는 기대로 카네이션과 꽃다발을... ',
#  'pubDate': 'Thu, 06 May 2021 15:12:00 +0900'}

# %%
len(temp_data['items'])
# Out:
# 10

# %%
df = pd.DataFrame(temp_data['items'])
df
# Out:
#                                                title  \
# 0            어머니 가슴이 아닌, 유리창에 카네이션을…코로나에 가슴 미어지는 자녀들
# 1              진천군, <b>어버이</b>의 <b>날</b> 맞이 물품꾸러미 전달
# 2                  농협생명, 농촌·지역사회 나눔 활동 'ESG 애쓰자' 캠페인
# 3  [유통오늘] 롯데홈쇼핑, <b>어버이날</b> 맞아 '건강백세꾸러미' 전달…NS홈쇼...
# 4                 한전 경기북부본부, 소외계층 <b>어버이날</b> 후원금 전달
# 5                    <b>어버이날</b> 맞이 중촌동 지역주민 후원금품 전달
# 6                     [포토]<b>어버이날</b> 앞두고 사랑의 삼계탕 나눔
# 7            신안군 증도면여성단체협의회 <b>어버이날</b> 카네이션 꽃바구니 전달
# 8                          석교동 복지만두레, 사랑의 孝 행복꾸러미 나눔
# 9                            상승세 탄 대구, 인천 상대로 5연승 도전
#
#                                         originallink  \
# 0     http://www.idaegu.com/newsView/idg202105060013
# 1  http://www.gukjenews.com/news/articleView.html...
# 2  http://www.newstomato.com/ReadNews.aspx?no=104...
# 3  http://www.sisaon.co.kr/news/articleView.html?...
# 4  https://www.dnews.co.kr/uhtml/view.jsp?idxno=2...
# 5  http://www.joongdo.co.kr/web/view.php?key=2021...
# ...

# %%
df.to_csv('c:/py_data/네이버오픈api_test.csv', encoding='cp949')

# %% [markdown]
# - 요청변수 추가

# %%
base_url ='https://openapi.naver.com/v1/search/news?query='
start_url = '&start='
dis_url = '&display='

# %%
keyword
# Out:
# '어버이날'

# %%
url = base_url + keyword + start_url + str(1) + dis_url + str(100)
url
# Out:
# 'https://openapi.naver.com/v1/search/news?query=어버이날&start=1&display=100'

# %%
response_data = requests.get(url, headers=headers)
response_data
temp_data = response_data.json()
temp_data
# Out:
# {'lastBuildDate': 'Thu, 06 May 2021 15:32:20 +0900',
#  'total': 124665,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '유리창 사이에 두고 <b>어버이날</b> 면회',
#    'originallink': 'https://www.news1.kr/photos/view/?4757223',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005335025',
#    'description': "<b>어버이날</b>을 앞둔 6일 서울 성동구 시립동부노인전문요양센터에 마련된 비대면 면회실 '가족의 거실'에서 박영순 할머니와 아들 강동훈 씨, 며느리 고의량 씨, 손자 강건우 군이 면회를 마치고 손으로 하트를 만들며... ",
#    'pubDate': 'Thu, 06 May 2021 15:30:00 +0900'},
#   {'title': "'코로나도 막지 못하는 가족의 사랑'",
#    'originallink': 'https://www.news1.kr/photos/view/?4757217',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005335023',
#    'description': "<b>어버이날</b>을 앞둔 6일 서울 성동구 시립동부노인전문요양센터에 마련된 비대면 면회실 '가족의 거실'에서 박영순 할머니와 아들 강동훈 씨, 며느리 고의량 씨, 손자 강건우 군이 면회를 마치고 손으로 하트를 만들며... ",
#    'pubDate': 'Thu, 06 May 2021 15:30:00 +0900'},
#   {'title': '김현준 LH 사장, 서울 번동5단지 현장 방문...그린리모델링 박차',
# ...

# %%
temp_data['items']
# Out:
# [{'title': '유리창 사이에 두고 <b>어버이날</b> 면회',
#   'originallink': 'https://www.news1.kr/photos/view/?4757223',
#   'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005335025',
#   'description': "<b>어버이날</b>을 앞둔 6일 서울 성동구 시립동부노인전문요양센터에 마련된 비대면 면회실 '가족의 거실'에서 박영순 할머니와 아들 강동훈 씨, 며느리 고의량 씨, 손자 강건우 군이 면회를 마치고 손으로 하트를 만들며... ",
#   'pubDate': 'Thu, 06 May 2021 15:30:00 +0900'},
#  {'title': "'코로나도 막지 못하는 가족의 사랑'",
#   'originallink': 'https://www.news1.kr/photos/view/?4757217',
#   'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005335023',
#   'description': "<b>어버이날</b>을 앞둔 6일 서울 성동구 시립동부노인전문요양센터에 마련된 비대면 면회실 '가족의 거실'에서 박영순 할머니와 아들 강동훈 씨, 며느리 고의량 씨, 손자 강건우 군이 면회를 마치고 손으로 하트를 만들며... ",
#   'pubDate': 'Thu, 06 May 2021 15:30:00 +0900'},
#  {'title': '김현준 LH 사장, 서울 번동5단지 현장 방문...그린리모델링 박차',
#   'originallink': 'http://www.kpinews.co.kr/news/articleView.html?idxno=146106',
# ...

# %%
len(temp_data['items'])
# Out:
# 100

# %%
df = pd.DataFrame(temp_data['items'])
df
# Out:
#                                     title  \
# 0               유리창 사이에 두고 <b>어버이날</b> 면회
# 1                    '코로나도 막지 못하는 가족의 사랑'
# 2   김현준 LH 사장, 서울 번동5단지 현장 방문...그린리모델링 박차
# 3                 충남개발공사, 도내 독거노인 후원물품 전달
# 4                     '유리벽 사이에 두고 나누는 사랑'
# ..                                    ...
# 95                     동해시, 사랑의 효도 지팡이 지원
# 96                          [동정] 이상천 제천시장
# 97                 어르신께 카네이션 달아드리는 오세훈 시장
# 98              김삼호 광산구청장, 오월어머니회와 간담회 가져
# 99                                 막걸리 한잔
#
#                                          originallink  \
# 0           https://www.news1.kr/photos/view/?4757223
# 1           https://www.news1.kr/photos/view/?4757217
# 2   http://www.kpinews.co.kr/news/articleView.html...
# 3   http://www.shinailbo.co.kr/news/articleView.ht...
# 4           https://www.news1.kr/photos/view/?4757221
# ..                                                ...
# 95  http://www.enewstoday.co.kr/news/articleView.h...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         100 non-null    object
#  1   originallink  100 non-null    object
#  2   link          100 non-null    object
#  3   description   100 non-null    object
#  4   pubDate       100 non-null    object
# dtypes: object(5)
# memory usage: 4.0+ KB

# %%
url = base_url + keyword + start_url + str(2) + dis_url + str(100)
response_data = requests.get(url, headers=headers)
response_data
temp_data = response_data.json()
temp_data
df = pd.DataFrame(temp_data['items'])
df.head()
# Out:
#                              title  \
# 0  스타키보청기, <b>어버이날</b> 맞아 이벤트 ‘풍성’
# 1                '카네이션 커다랗게 만들었어요'
# 2                   '엄마 카네이션 받으세요'
# 3                  <b>어버이날</b> D-2
# 4                  <b>어버이날</b> D-2
#
#                                         originallink  \
# 0  http://www.mdtoday.co.kr/mdtoday/index.html?no...
# 1       http://yna.kr/PYH20210506171100054?did=1196m
# 2       http://yna.kr/PYH20210506171600054?did=1196m
# 3  http://www.newsis.com/view/?id=NISI20210506_00...
# 4  http://www.newsis.com/view/?id=NISI20210506_00...
#
#                                                 link  \
# 0  http://www.mdtoday.co.kr/mdtoday/index.html?no...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  https://news.naver.com/main/read.nhn?mode=LSD&...
# 4  https://news.naver.com/main/read.nhn?mode=LSD&...
#
#                                          description  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         100 non-null    object
#  1   originallink  100 non-null    object
#  2   link          100 non-null    object
#  3   description   100 non-null    object
#  4   pubDate       100 non-null    object
# dtypes: object(5)
# memory usage: 4.0+ KB

# %%
# !pip install tqdm

# %%
import time

# %%
time.sleep(3)

# %%
RANGE = range(1,10)
test_lst = []
for i in RANGE:
    url = base_url + keyword + start_url + str(i) + dis_url + str(100)
    response_data = requests.get(url, headers=headers)
    temp_data = response_data.json()
    test_lst.extend(temp_data['items'])
    time.sleep(3)
df = pd.DataFrame(test_lst)
df.head()
# Out:
#                                                title  \
# 0              한국장애인녹색환경연합,<b>어버이날</b> 맞이‘사랑나눔 물품전달’
# 1  [SR경제&amp;라이프] 형제꽃송이버섯, <b>어버이날</b> 부모님 선물세트 특...
# 2                                   '멜빵 카네이션' 입은 아이들
# 3  남양주시 오남읍 주민자치위원회, <b>어버이날</b> 맞아 관내 어르신들께 종이 카...
# 4                                         가정의 달을 계기로
#
#                                         originallink  \
# 0  https://news.imaeil.com/People/202105061555468...
# 1  http://www.srtimes.kr/news/articleView.html?id...
# 2          https://www.news1.kr/photos/view/?4757453
# 3  http://www.kmaeil.com/news/articleView.html?id...
# 4  http://www.ccdailynews.com/news/articleView.ht...
#
#                                                 link  \
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  http://www.srtimes.kr/news/articleView.html?id...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# 3  http://www.kmaeil.com/news/articleView.html?id...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         900 non-null    object
#  1   originallink  900 non-null    object
#  2   link          900 non-null    object
#  3   description   900 non-null    object
#  4   pubDate       900 non-null    object
# dtypes: object(5)
# memory usage: 35.3+ KB
