# %%
import pandas as pd
df_car = pd.read_excel('c:/py_data/car_in_seoul.xls', header = 1,
                      usecols='A,B,C,G,K,O,S')
df_car.head()
# Out:
#      기간  자치구       소계     소계.1    소계.2    소계.3  소계.4
# 0  2017  서울시  3116256  2641190  127564  339921  7581
# 1  2017  종로구    50828    41115    4055    5469   189
# 2  2017   중구    51540    40523    3508    7294   215
# 3  2017  용산구    77458    67335    2783    7221   119
# 4  2017  성동구   103116    87762    3698   11459   197

# %%
df_par = pd.read_excel('c:/py_data/par_in_seoul.xls', header = 2,
                      usecols='A,B,C,I,O,W')
df_par.head()
# Out:
#      기간  자치구      개소  개소.3  개소.6   개소.10
# 0  2017  서울시  308025  8576  1977  297472
# 1  2017  종로구    7220   148   103    6969
# 2  2017   중구    4152   151    94    3907
# 3  2017  용산구    7291   362    75    6854
# 4  2017  성동구    6658   264    65    6329

# %%
df_car.rename(columns={'기간':'년도',
                       '소계':'합계',
                       '소계.1':'승용차',
                       '소계.2':'승합차',
                       '소계.3':'화물차',
                       '소계.4':'특수차'}, inplace=True)
df_car.head()
# Out:
#      년도  자치구       합계      승용차     승합차     화물차   특수차
# 0  2017  서울시  3116256  2641190  127564  339921  7581
# 1  2017  종로구    50828    41115    4055    5469   189
# 2  2017   중구    51540    40523    3508    7294   215
# 3  2017  용산구    77458    67335    2783    7221   119
# 4  2017  성동구   103116    87762    3698   11459   197

# %%
df_par.rename(columns={'기간':'년도',
                       '개소':'합계',
                       '개소.3':'노상',
                       '개소.6':'노외',
                       '개소.10':'건축물부설'}, inplace=True)
df_par.head()
# Out:
#      년도  자치구      합계    노상    노외   건축물부설
# 0  2017  서울시  308025  8576  1977  297472
# 1  2017  종로구    7220   148   103    6969
# 2  2017   중구    4152   151    94    3907
# 3  2017  용산구    7291   362    75    6854
# 4  2017  성동구    6658   264    65    6329

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      27 non-null     int64
#  1   자치구     27 non-null     object
#  2   합계      27 non-null     object
#  3   승용차     27 non-null     object
#  4   승합차     27 non-null     object
#  5   화물차     27 non-null     object
#  6   특수차     27 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.6+ KB

# %%
df_par.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      26 non-null     int64
#  1   자치구     26 non-null     object
#  2   합계      26 non-null     int64
#  3   노상      26 non-null     int64
#  4   노외      26 non-null     int64
#  5   건축물부설   26 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.3+ KB

# %%
df_car
# Out:
#       년도   자치구       합계      승용차     승합차     화물차   특수차
# 0   2017   서울시  3116256  2641190  127564  339921  7581
# 1   2017   종로구    50828    41115    4055    5469   189
# 2   2017    중구    51540    40523    3508    7294   215
# 3   2017   용산구    77458    67335    2783    7221   119
# 4   2017   성동구   103116    87762    3698   11459   197
# 5   2017   광진구    98631    82951    4169   11248   263
# 6   2017  동대문구    97507    79837    4249   13244   177
# 7   2017   중랑구   113916    92596    5305   15619   396
# 8   2017   성북구   117209   100028    5745   11311   125
# 9   2017   강북구    77820    63987    4268    9416   149
# 10  2017   도봉구    97323    82048    4129   10937   209
# 11  2017   노원구   154708   134400    6291   13708   309
# 12  2017   은평구   129004   109372    5745   13636   251
# 13  2017  서대문구    86068    73356    3646    8764   302
# 14  2017   마포구   116531    99278    4662   12352   239
# 15  2017   양천구   150823   128605    5648   16034   536
# ...

# %%
df_par
# Out:
#       년도   자치구      합계    노상    노외   건축물부설
# 0   2017   서울시  308025  8576  1977  297472
# 1   2017   종로구    7220   148   103    6969
# 2   2017    중구    4152   151    94    3907
# 3   2017   용산구    7291   362    75    6854
# 4   2017   성동구    6658   264    65    6329
# 5   2017   광진구   16304   359    70   15875
# 6   2017  동대문구    9485    30    57    9398
# 7   2017   중랑구   12170   525    81   11564
# 8   2017   성북구   13038   125   154   12759
# 9   2017   강북구   10528    23    59   10446
# 10  2017   도봉구    9593   460    61    9072
# 11  2017   노원구    6612   154    45    6413
# 12  2017   은평구   19119   109    82   18928
# 13  2017  서대문구   11835   626    96   11113
# 14  2017   마포구   13905    29    87   13789
# 15  2017   양천구   11811   488    56   11267
# 16  2017   강서구   18630   696    56   17878
# 17  2017   구로구   10219   299    58    9862
# 18  2017   금천구    9393    33    53    9307
# 19  2017  영등포구   10018  2177    69    7772
# 20  2017   동작구   13313    79    83   13151
# ...

# %%
df_car.drop([0], inplace=True)
df_car.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차
# 1  2017  종로구   50828  41115  4055   5469  189
# 2  2017   중구   51540  40523  3508   7294  215
# 3  2017  용산구   77458  67335  2783   7221  119
# 4  2017  성동구  103116  87762  3698  11459  197
# 5  2017  광진구   98631  82951  4169  11248  263

# %%
df_par.drop([0], inplace=True)
df_par.head()
# Out:
#      년도  자치구     합계   노상   노외  건축물부설
# 1  2017  종로구   7220  148  103   6969
# 2  2017   중구   4152  151   94   3907
# 3  2017  용산구   7291  362   75   6854
# 4  2017  성동구   6658  264   65   6329
# 5  2017  광진구  16304  359   70  15875

# %%
df_car.drop([26],inplace=True)
df_car.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차
# 1  2017  종로구   50828  41115  4055   5469  189
# 2  2017   중구   51540  40523  3508   7294  215
# 3  2017  용산구   77458  67335  2783   7221  119
# 4  2017  성동구  103116  87762  3698  11459  197
# 5  2017  광진구   98631  82951  4169  11248  263

# %%
df_car
# Out:
#       년도   자치구      합계     승용차   승합차    화물차   특수차
# 1   2017   종로구   50828   41115  4055   5469   189
# 2   2017    중구   51540   40523  3508   7294   215
# 3   2017   용산구   77458   67335  2783   7221   119
# 4   2017   성동구  103116   87762  3698  11459   197
# 5   2017   광진구   98631   82951  4169  11248   263
# 6   2017  동대문구   97507   79837  4249  13244   177
# 7   2017   중랑구  113916   92596  5305  15619   396
# 8   2017   성북구  117209  100028  5745  11311   125
# 9   2017   강북구   77820   63987  4268   9416   149
# 10  2017   도봉구   97323   82048  4129  10937   209
# 11  2017   노원구  154708  134400  6291  13708   309
# 12  2017   은평구  129004  109372  5745  13636   251
# 13  2017  서대문구   86068   73356  3646   8764   302
# 14  2017   마포구  116531   99278  4662  12352   239
# 15  2017   양천구  150823  128605  5648  16034   536
# 16  2017   강서구  202063  171936  8007  21740   380
# 17  2017   구로구  143960  119141  6805  17717   297
# 18  2017   금천구   86427   68119  4602  13565   141
# ...

# %%
df_par
# Out:
#       년도   자치구     합계    노상   노외  건축물부설
# 1   2017   종로구   7220   148  103   6969
# 2   2017    중구   4152   151   94   3907
# 3   2017   용산구   7291   362   75   6854
# 4   2017   성동구   6658   264   65   6329
# 5   2017   광진구  16304   359   70  15875
# 6   2017  동대문구   9485    30   57   9398
# 7   2017   중랑구  12170   525   81  11564
# 8   2017   성북구  13038   125  154  12759
# 9   2017   강북구  10528    23   59  10446
# 10  2017   도봉구   9593   460   61   9072
# 11  2017   노원구   6612   154   45   6413
# 12  2017   은평구  19119   109   82  18928
# 13  2017  서대문구  11835   626   96  11113
# 14  2017   마포구  13905    29   87  13789
# 15  2017   양천구  11811   488   56  11267
# 16  2017   강서구  18630   696   56  17878
# 17  2017   구로구  10219   299   58   9862
# 18  2017   금천구   9393    33   53   9307
# 19  2017  영등포구  10018  2177   69   7772
# 20  2017   동작구  13313    79   83  13151
# 21  2017   관악구  19504    29   85  19390
# 22  2017   서초구  13360   829   90  12441
# ...

# %%
df_car['합계'] = df_car['합계'].astype(int)
df_car['승용차'] = df_car['승용차'].astype(int)
df_car['승합차'] = df_car['승합차'].astype(int)
df_car['화물차'] = df_car['화물차'].astype(int)
df_car['특수차'] = df_car['특수차'].astype(int)
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1 to 25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      25 non-null     int64
#  1   자치구     25 non-null     object
#  2   합계      25 non-null     int32
#  3   승용차     25 non-null     int32
#  4   승합차     25 non-null     int32
#  5   화물차     25 non-null     int32
#  6   특수차     25 non-null     int32
# dtypes: int32(5), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
# df_car에
# 승용차비율, 승합차 비율, 화물차비율
# 계산필드 추가
df_car['승용차비율']=df_car['승용차']/df_car['합계']*100
df_car['승합차비율']=df_car['승합차']/df_car['합계']*100
df_car['화물차비율']=df_car['화물차']/df_car['합계']*100
df_car.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차      승용차비율     승합차비율      화물차비율
# 1  2017  종로구   50828  41115  4055   5469  189  80.890454  7.977886  10.759817
# 2  2017   중구   51540  40523  3508   7294  215  78.624369  6.806364  14.152115
# 3  2017  용산구   77458  67335  2783   7221  119  86.930982  3.592915   9.322472
# 4  2017  성동구  103116  87762  3698  11459  197  85.109973  3.586252  11.112727
# 5  2017  광진구   98631  82951  4169  11248  263  84.102361  4.226866  11.404122

# %%
# 노상비율, 노외비율, 건축물비율 계산필드 추가
df_par['노상비율']=df_par['노상']/df_par['합계']*100
df_par['노외비율']=df_par['노외']/df_par['합계']*100
df_par['건축물비율']=df_par['건축물부설']/df_par['합계']*100
df_par.head()
# Out:
#      년도  자치구     합계   노상   노외  건축물부설      노상비율      노외비율      건축물비율
# 1  2017  종로구   7220  148  103   6969  2.049861  1.426593  96.523546
# 2  2017   중구   4152  151   94   3907  3.636802  2.263969  94.099229
# 3  2017  용산구   7291  362   75   6854  4.965025  1.028665  94.006309
# 4  2017  성동구   6658  264   65   6329  3.965155  0.976269  95.058576
# 5  2017  광진구  16304  359   70  15875  2.201914  0.429342  97.368744

# %%
df_car1 = df_car
df_car1.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차      승용차비율     승합차비율      화물차비율
# 1  2017  종로구   50828  41115  4055   5469  189  80.890454  7.977886  10.759817
# 2  2017   중구   51540  40523  3508   7294  215  78.624369  6.806364  14.152115
# 3  2017  용산구   77458  67335  2783   7221  119  86.930982  3.592915   9.322472
# 4  2017  성동구  103116  87762  3698  11459  197  85.109973  3.586252  11.112727
# 5  2017  광진구   98631  82951  4169  11248  263  84.102361  4.226866  11.404122

# %%
del df_car1['승용차비율']

# %%
df_car.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차     승합차비율      화물차비율
# 1  2017  종로구   50828  41115  4055   5469  189  7.977886  10.759817
# 2  2017   중구   51540  40523  3508   7294  215  6.806364  14.152115
# 3  2017  용산구   77458  67335  2783   7221  119  3.592915   9.322472
# 4  2017  성동구  103116  87762  3698  11459  197  3.586252  11.112727
# 5  2017  광진구   98631  82951  4169  11248  263  4.226866  11.404122

# %%
df_car1['승용차비율']=df_car['승용차']/df_car['합계']*100

# %%
df_car1 = df_car.copy()
df_par1 = df_par.copy()

# %%
df_car1.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차     승합차비율      화물차비율      승용차비율
# 1  2017  종로구   50828  41115  4055   5469  189  7.977886  10.759817  80.890454
# 2  2017   중구   51540  40523  3508   7294  215  6.806364  14.152115  78.624369
# 3  2017  용산구   77458  67335  2783   7221  119  3.592915   9.322472  86.930982
# 4  2017  성동구  103116  87762  3698  11459  197  3.586252  11.112727  85.109973
# 5  2017  광진구   98631  82951  4169  11248  263  4.226866  11.404122  84.102361

# %%
del df_car1['승용차비율']
df_car1.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차     승합차비율      화물차비율
# 1  2017  종로구   50828  41115  4055   5469  189  7.977886  10.759817
# 2  2017   중구   51540  40523  3508   7294  215  6.806364  14.152115
# 3  2017  용산구   77458  67335  2783   7221  119  3.592915   9.322472
# 4  2017  성동구  103116  87762  3698  11459  197  3.586252  11.112727
# 5  2017  광진구   98631  82951  4169  11248  263  4.226866  11.404122

# %%
df_car.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차     승합차비율      화물차비율      승용차비율
# 1  2017  종로구   50828  41115  4055   5469  189  7.977886  10.759817  80.890454
# 2  2017   중구   51540  40523  3508   7294  215  6.806364  14.152115  78.624369
# 3  2017  용산구   77458  67335  2783   7221  119  3.592915   9.322472  86.930982
# 4  2017  성동구  103116  87762  3698  11459  197  3.586252  11.112727  85.109973
# 5  2017  광진구   98631  82951  4169  11248  263  4.226866  11.404122  84.102361

# %%
# df_car1에 불필요한 필드
# 승용차, 승합차, 화물차, 특수차 삭제
del df_car1['승용차']
del df_car1['승합차']
del df_car1['화물차']
del df_car1['특수차']
df_car1.head()
# Out:
#      년도  자치구      합계     승합차비율      화물차비율
# 1  2017  종로구   50828  7.977886  10.759817
# 2  2017   중구   51540  6.806364  14.152115
# 3  2017  용산구   77458  3.592915   9.322472
# 4  2017  성동구  103116  3.586252  11.112727
# 5  2017  광진구   98631  4.226866  11.404122

# %%
df_car1.head()
# Out:
#      년도  자치구      합계     승합차비율      화물차비율      승용차비율
# 1  2017  종로구   50828  7.977886  10.759817  80.890454
# 2  2017   중구   51540  6.806364  14.152115  78.624369
# 3  2017  용산구   77458  3.592915   9.322472  86.930982
# 4  2017  성동구  103116  3.586252  11.112727  85.109973
# 5  2017  광진구   98631  4.226866  11.404122  84.102361

# %%
del df_par1['노상']
del df_par1['노외']
del df_par1['건축물부설']
df_par1.head(2)
# Out:
#      년도  자치구    합계      노상비율      노외비율      건축물비율
# 1  2017  종로구  7220  2.049861  1.426593  96.523546
# 2  2017   중구  4152  3.636802  2.263969  94.099229

# %%
data_seoul = pd.merge(df_car1, df_par1, on = '자치구')
data_seoul.head()
# Out:
#    년도_x  자치구    합계_x     승합차비율      화물차비율      승용차비율  년도_y   합계_y      노상비율  \
# 0  2017  종로구   50828  7.977886  10.759817  80.890454  2017   7220  2.049861
# 1  2017   중구   51540  6.806364  14.152115  78.624369  2017   4152  3.636802
# 2  2017  용산구   77458  3.592915   9.322472  86.930982  2017   7291  4.965025
# 3  2017  성동구  103116  3.586252  11.112727  85.109973  2017   6658  3.965155
# 4  2017  광진구   98631  4.226866  11.404122  84.102361  2017  16304  2.201914
#
#        노외비율      건축물비율
# 0  1.426593  96.523546
# 1  2.263969  94.099229
# 2  1.028665  94.006309
# 3  0.976269  95.058576
# 4  0.429342  97.368744

# %%
del data_seoul['년도_y']
data_seoul.rename(columns={'합계_x':'차량합계',
                           '합계_y':'주차장합계',
                           '년도_x':'년도'}, inplace=True)
# data_seoul에서 자치구를 인덱스 키로 변경합니다.
data_seoul.set_index('자치구', inplace=True)
data_seoul.head(2)
# Out:
#        년도   차량합계     승합차비율      화물차비율      승용차비율  주차장합계      노상비율      노외비율  \
# 자치구
# 종로구  2017  50828  7.977886  10.759817  80.890454   7220  2.049861  1.426593
# 중구   2017  51540  6.806364  14.152115  78.624369   4152  3.636802  2.263969
#
#          건축물비율
# 자치구
# 종로구  96.523546
# 중구   94.099229

# %%
# 완성된 데이터를 이용하여 차트를 출력합니다.
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fl = fm.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name()
plt.rc('font', family=fl)

# %%
ax = data_seoul[['차량합계','주차장합계']].plot(kind='bar',
                                                title='주차장',
                                                figsize=(12,4),
                                                legend=True,
                                                fontsize=12)
ax.set_xlabel('자치구',fontsize=12)
ax.set_ylabel('차량/주차장', fontsize=12)
ax.legend(['차량','주차장'], fontsize=12)
plt.show()

# %%
# 데이터프레임.loc['인덱스명']   -   행단위 데이터 읽기(행 이름으로)
data_seoul.loc['종로구']
# Out:
# 년도        2017.000000
# 차량합계     50828.000000
# 승합차비율        7.977886
# 화물차비율       10.759817
# 승용차비율       80.890454
# 주차장합계     7220.000000
# 노상비율         2.049861
# 노외비율         1.426593
# 건축물비율       96.523546
# Name: 종로구, dtype: float64

# %%
data_seoul.loc[['영등포구','종로구','구로구','강서구']]
# Out:
#         년도    차량합계     승합차비율      화물차비율      승용차비율  주차장합계       노상비율  \
# 자치구
# 영등포구  2017  146150  4.249743  13.971947  81.030448  10018  21.730884
# 종로구   2017   50828  7.977886  10.759817  80.890454   7220   2.049861
# 구로구   2017  143960  4.727008  12.306891  82.759794  10219   2.925922
# 강서구   2017  202063  3.962626  10.759021  85.090294  18630   3.735910
#
#           노외비율      건축물비율
# 자치구
# 영등포구  0.688760  77.580355
# 종로구   1.426593  96.523546
# 구로구   0.567570  96.506507
# 강서구   0.300590  95.963500

# %%
# 데이터프레임.iloc[인덱스번호]  -   행 번호로
data_seoul.iloc[0]
# Out:
# 년도        2017.000000
# 차량합계     50828.000000
# 승합차비율        7.977886
# 화물차비율       10.759817
# 승용차비율       80.890454
# 주차장합계     7220.000000
# 노상비율         2.049861
# 노외비율         1.426593
# 건축물비율       96.523546
# Name: 종로구, dtype: float64

# %%
data_seoul.iloc[0:6]
# Out:
#         년도    차량합계     승합차비율      화물차비율      승용차비율  주차장합계      노상비율      노외비율  \
# 자치구
# 종로구   2017   50828  7.977886  10.759817  80.890454   7220  2.049861  1.426593
# 중구    2017   51540  6.806364  14.152115  78.624369   4152  3.636802  2.263969
# 용산구   2017   77458  3.592915   9.322472  86.930982   7291  4.965025  1.028665
# 성동구   2017  103116  3.586252  11.112727  85.109973   6658  3.965155  0.976269
# 광진구   2017   98631  4.226866  11.404122  84.102361  16304  2.201914  0.429342
# 동대문구  2017   97507  4.357636  13.582615  81.878224   9485  0.316289  0.600949
#
#           건축물비율
# 자치구
# 종로구   96.523546
# 중구    94.099229
# 용산구   94.006309
# 성동구   95.058576
# 광진구   97.368744
# 동대문구  99.082762

# %%
data_seoul.loc['중구':'동대문구']
# Out:
#         년도    차량합계     승합차비율      화물차비율      승용차비율  주차장합계      노상비율      노외비율  \
# 자치구
# 중구    2017   51540  6.806364  14.152115  78.624369   4152  3.636802  2.263969
# 용산구   2017   77458  3.592915   9.322472  86.930982   7291  4.965025  1.028665
# 성동구   2017  103116  3.586252  11.112727  85.109973   6658  3.965155  0.976269
# 광진구   2017   98631  4.226866  11.404122  84.102361  16304  2.201914  0.429342
# 동대문구  2017   97507  4.357636  13.582615  81.878224   9485  0.316289  0.600949
#
#           건축물비율
# 자치구
# 중구    94.099229
# 용산구   94.006309
# 성동구   95.058576
# 광진구   97.368744
# 동대문구  99.082762

# %%
data_seoul1 = data_seoul.loc[['강서구','강남구',
                             '서초구','송파구',
                             '영등포구','동대문구',
                             '종로구']]
data_seoul1
# Out:
#         년도    차량합계     승합차비율      화물차비율      승용차비율  주차장합계       노상비율  \
# 자치구
# 강서구   2017  202063  3.962626  10.759021  85.090294  18630   3.735910
# 강남구   2017  238311  2.861807   7.196479  89.780161  20348   0.353843
# 서초구   2017  181546  3.042755   9.657057  87.114560  13360   6.205090
# 송파구   2017  231819  3.312929  11.285529  85.265228  18009   2.704203
# 영등포구  2017  146150  4.249743  13.971947  81.030448  10018  21.730884
# 동대문구  2017   97507  4.357636  13.582615  81.878224   9485   0.316289
# 종로구   2017   50828  7.977886  10.759817  80.890454   7220   2.049861
#
#           노외비율      건축물비율
# 자치구
# 강서구   0.300590  95.963500
# 강남구   0.570081  99.076076
# 서초구   0.673653  93.121257
# 송파구   0.832917  96.462880
# 영등포구  0.688760  77.580355
# 동대문구  0.600949  99.082762
# 종로구   1.426593  96.523546

# %%
ax = data_seoul1[['차량합계','주차장합계']].plot(kind='bar',
                                                title='주차장',
                                                figsize=(12,4),
                                                legend=True,
                                                fontsize=12)
ax.set_xlabel('자치구',fontsize=12)
ax.set_ylabel('차량/주차장', fontsize=12)
ax.legend(['차량','주차장'], fontsize=12)
plt.show()
