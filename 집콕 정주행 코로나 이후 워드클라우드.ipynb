# %%
import pandas as pd

# %%
after_cd = pd.read_csv('c:/py_data/py_project/After 코로나 단어집계(집콕정주행).csv', encoding='cp949')

# %%
del after_cd['Unnamed: 0']
after_cd
# Out:
#         단어    횟수
# 0      드라마  4505
# 1       추천  2026
# 2       보고  1541
# 3       시간  1345
# 4       영화  1303
# ...    ...   ...
# 22013  루쿠항     1
# 22014  류지연     1
# 22015  류현경     1
# 22016   롱내     1
# 22017  힝년생     1
#
# [22018 rows x 2 columns]

# %%
after_cd.drop(after_cd.index[4], inplace=True)
after_cd
# Out:
#          단어    횟수
# 0       드라마  4505
# 3        시간  1345
# 4        영화  1303
# 5      넷플릭스  1287
# 9       코로나  1152
# ...     ...   ...
# 22013   루쿠항     1
# 22014   류지연     1
# 22015   류현경     1
# 22016    롱내     1
# 22017   힝년생     1
#
# [22013 rows x 2 columns]

# %%
cd = dict(after_cd.values.tolist())
cd
# Out:
# {'드라마': 4505,
#  '시간': 1345,
#  '영화': 1303,
#  '넷플릭스': 1287,
#  '코로나': 1152,
#  '생각': 1061,
#  '다시': 1054,
#  '집': 1051,
#  '전': 960,
#  '것': 942,
#  '시작': 926,
#  '사람': 832,
#  '거': 808,
#  '아이': 784,
#  '요': 773,
#  '때': 754,
#  '사랑': 747,
#  '더': 732,
#  '배우': 711,
#  '보기': 694,
#  '하나': 689,
#  '제': 679,
#  '정말': 675,
#  '지금': 671,
#  '오늘': 658,
#  '하루': 655,
#  '주말': 639,
#  '생활': 618,
#  '크리스마스': 604,
#  '이번': 598,
#  '시리즈': 567,
#  '우리': 549,
#  '좀': 544,
#  '재미': 542,
#  '이야기': 538,
#  '또': 537,
#  '작품': 497,
#  '마음': 466,
#  '웹툰': 466,
#  '그': 452,
#  '한번': 443,
#  '도': 441,
#  '미드': 438,
#  '그냥': 436,
#  '이': 425,
#  '완전': 422,
#  '티비': 415,
#  '수': 411,
#  '꼭': 409,
#  '볼': 400,
#  '연기': 398,
#  '사진': 396,
#  '해': 386,
#  '모두': 385,
#  '중': 375,
#  '주인공': 371,
#  '애': 367,
#  '영상': 364,
#  '느낌': 358,
#  '비밀': 357,
#  '마지막': 355,
#  '내용': 355,
#  '일': 354,
#  '나': 346,
#  '중이': 345,
#  '엄마': 343,
#  '다른': 341,
#  '넷플': 340,
#  '해리포터': 340,
#  '뭐': 339,
#  '바로': 337,
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import random
img_path = 'c:/py_data/TV.jpg'
cloud_mask = np.array(Image.open(img_path))


wordcloud = WordCloud(font_path="c:/Windows/Fonts/malgun.ttf", 
                      colormap='OrRd',
                      background_color="white", mask=cloud_mask)
wc = wordcloud.generate_from_frequencies(cd)
plt.figure(figsize=(30,40))
plt.imshow(wc)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
